# %%
from IPython.core.display import HTML, display
from string import Template
import pandas as pd
import json, random

# %%
HTML("<script src='d3.js'></script>")
# Out:
# <script src='d3.js'></script>

# %%
df = pd.read_excel("Line_chart.xlsx",sep="\t")

# %%
df.head()
# Out:
#    Currency     KZT
# 0         1  3.1185
# 1         2  5.6826
# 2         3  4.2807
# 3         4  5.0761
# 4         5  0.6515

# %%
df_dict = df.to_dict(orient="records")
df_dict[:5]
# Out:
# [{'Currency': 1, 'KZT': 3.1185},
#  {'Currency': 2, 'KZT': 5.6826},
#  {'Currency': 3, 'KZT': 4.2806999999999995},
#  {'Currency': 4, 'KZT': 5.0761},
#  {'Currency': 5, 'KZT': 0.6515000000000001}]

# %%
js_text_template = Template('''

var margin = {top:20,right:20,bottom:30,left:30};
var width = 850 - (margin.left + margin.right);
var height = 300 - (margin.top + margin.bottom);

console.log("1",width)

var x = d3.scale.linear().range([0,width]);
var y = d3.scale.linear().range([height,0]);
var color = d3.scale.category10();


var xAxis = d3.svg.axis()
.scale(x)
.orient("bottom");

var yAxis = d3.svg.axis()
.scale(y)
.orient("left");

var svg = d3.select("#$maid").append("svg")
.attr("width", width + margin.left+margin.left)
.attr("height", height + margin.top+margin.bottom)
.append("g")
.attr("transform","translate("+margin.left+","+margin.top+")")

var data = $python_data;

data.forEach(function(d) {

});

var line = d3.svg.line()
.x(function(d) { return x(d.Currency); })
.y(function(d) { return y(d.KZT); })
.interpolate('linear');


x.domain(d3.extent(data,function(d) { return d.Currency;}))
y.domain(d3.extent(data,function(d) { return d.KZT;}));



console.log("Extent",d3.extent(data,function(d) { return d.KZT}));

svg.append("g")
.attr("class","x axis")
.attr("transform","translate(40,"+height+")")
.call(xAxis)
.append("text")
.attr("class","label")
.attr("x",width)
.style("text-anchor","end")
.text("Currency");

svg.append("g")
.attr("class","y axis")
.call(yAxis)
.append("text")
.attr("transform","rotate(-90)")
.attr("class","label")
.attr("y",6)
.attr("dy",".8em")
.style("text-anchor","end")
.text("KZT, hundred");

svg.append("path")
.datum(data)
.attr("fill", "none")
.attr("stroke", "steelblue")
.attr("stroke-linejoin", "round")
.attr("stroke-linecap", "round")
.attr("stroke-width", 1.5)
.attr("d", line);

svg.selectAll(".dot")
.data(data)
.enter()
.append("circle")
.attr("class","dot")
.attr("r",3.5)
.attr("cx", function(d) { return x(d.Currency);})
.attr("cy", function(d) { return y(d.KZT);})
.style("fill",function(d) { return color(d.species);});

console.log("3",x)



''');

# %%
html_template = Template('''
    <style>
    
    .line{
        
        stroke: "steelblue"
    }
    .legend{
        color:blue;
    }
    
    .axis path,
    .axis line{
        fill: none;
        shape-rendering:crispEdges;
    
    }
    </style>
    <div id="scatter-id"></div>
    <script>$js_text</script>
''')
js_text = js_text_template.substitute({
    "python_data":json.dumps(df_dict),
    "maid":"scatter-id"
})

HTML(html_template.substitute({'js_text':js_text}))
# Out:
#     <style>
#
#     .line{
#
#         stroke: "steelblue"
#     }
#     .legend{
#         color:blue;
#     }
#
#     .axis path,
#     .axis line{
#         fill: none;
#         shape-rendering:crispEdges;
#
#     }
#     </style>
#     <div id="scatter-id"></div>
#     <script>
#
# var margin = {top:20,right:20,bottom:30,left:30};
# var width = 850 - (margin.left + margin.right);
# var height = 300 - (margin.top + margin.bottom);
#
# console.log("1",width)
#
# var x = d3.scale.linear().range([0,width]);
# var y = d3.scale.linear().range([height,0]);
# var color = d3.scale.category10();
#
#
# var xAxis = d3.svg.axis()
# .scale(x)
# .orient("bottom");
#
# var yAxis = d3.svg.axis()
# .scale(y)
# .orient("left");
#
# var svg = d3.select("#scatter-id").append("svg")
# .attr("width", width + margin.left+margin.left)
# .attr("height", height + margin.top+margin.bottom)
# .append("g")
# .attr("transform","translate("+margin.left+","+margin.top+")")
#
# var data = [{"Currency": 1, "KZT": 3.1185}, {"Currency": 2, "KZT": 5.6826}, {"Currency": 3, "KZT": 4.2806999999999995}, {"Currency": 4, "KZT": 5.0761}, {"Currency": 5, "KZT": 0.6515000000000001}, {"Currency": 6, "KZT": 6.0927}, {"Currency": 7, "KZT": 3.1869}, {"Currency": 8, "KZT": 4.6999}, {"Currency": 9, "KZT": 1.6781}, {"Currency": 10, "KZT": 2.5284999999999997}];
#
# data.forEach(function(d) {
#
# });
#
# var line = d3.svg.line()
# .x(function(d) { return x(d.Currency); })
# .y(function(d) { return y(d.KZT); })
# .interpolate('linear');
#
#
# x.domain(d3.extent(data,function(d) { return d.Currency;}))
# y.domain(d3.extent(data,function(d) { return d.KZT;}));
#
#
#
# console.log("Extent",d3.extent(data,function(d) { return d.KZT}));
#
# svg.append("g")
# .attr("class","x axis")
# .attr("transform","translate(40,"+height+")")
# .call(xAxis)
# .append("text")
# .attr("class","label")
# .attr("x",width)
# .style("text-anchor","end")
# .text("Currency");
#
# svg.append("g")
# .attr("class","y axis")
# .call(yAxis)
# .append("text")
# .attr("transform","rotate(-90)")
# .attr("class","label")
# .attr("y",6)
# .attr("dy",".8em")
# .style("text-anchor","end")
# .text("KZT, hundred");
#
# svg.append("path")
# .datum(data)
# .attr("fill", "none")
# .attr("stroke", "steelblue")
# .attr("stroke-linejoin", "round")
# .attr("stroke-linecap", "round")
# .attr("stroke-width", 1.5)
# .attr("d", line);
#
# svg.selectAll(".dot")
# .data(data)
# .enter()
# .append("circle")
# .attr("class","dot")
# .attr("r",3.5)
# .attr("cx", function(d) { return x(d.Currency);})
# .attr("cy", function(d) { return y(d.KZT);})
# .style("fill",function(d) { return color(d.species);});
#
# console.log("3",x)
#
#
#
# </script>
